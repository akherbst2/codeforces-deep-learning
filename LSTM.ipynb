# %%
import pandas
import collections

df = pandas.read_csv('output_all.csv')
allWords = df['main_text'].str.cat(sep=' ').split(' ')

def build_dataset(words):
    count = collections.Counter(words).most_common()
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reverse_dictionary

vocabularyF, vocabularyR = build_dataset(allWords)

def RNN(x, weights, biases):

    # reshape to [1, n_input]
    x = tf.reshape(x, [-1, n_input])

    # Generate a n_input-element sequence of inputs
    # (eg. [had] [a] [general] -> [20] [6] [33])
    x = tf.split(x,n_input,1)

    # 1-layer LSTM with n_hidden units.
    rnn_cell = rnn.BasicLSTMCell(n_hidden)

    # generate prediction
    outputs, states = rnn.static_rnn(rnn_cell, x, dtype=tf.float32)

    # there are n_input outputs but
    # we only want the last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

vocab_size = len(vocabularyF)
n_input = 3

# number of units in RNN cell
n_hidden = 512

# RNN output node weights and biases
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, vocab_size]))
}
biases = {
    'out': tf.Variable(tf.random_normal([vocab_size]))
}

# %%
temp = [i[2:][:-2].split('/') for i in list(df['tags'])]

# %%
df
# Out:
#       contest                                input_specification letter  \
# 0           1  The input contains three positive integer numb...      A
# 1           1  The first line of the input contains integer n...      B
# 2           1  The input file consists of three lines each of...      C
# 3          10  The first line contains 6 integer numbers n P1...      A
# 4          10  The first line contains two integers N and K 1...      B
# 5          10  The first line contains the only number N 1 N 106      C
# 6          10  The first line contains an integer n 1 n 500 t...      D
# 7          10  The first line contains an integer n 1 n 400 t...      E
# 8         100  The input consists of three integer numbers n ...      A
# 9         100  The first line contains n 1 n 1000 where n the...      B
# 10        100  You are given two integers a and b one per lin...      C
# 11        100  The first line contains a single integer n 2 n...      D
# 12        100  The first line of input contains a single inte...      E
# 13        100  The first line of the input contains n 1 n 9 T...      F
# 14        100  The first line contains a single integer n 0 n...      G
# 15        100  The first line contains number n 1 n 10 the nu...      H
# 16        100  A single integer k 0 k 360 is given in the fir...      I
# 17        100  The first line contains a single integer n 1 n...      J
# 18        101  The first input data line contains a string wh...      A
# 19        101  The first line contains two space-separated in...      B
# 20        101  The first line contains integers x1 y1 the coo...      C
# 21        101  The first line contains the only integer n 2 n...      D
# 22        101  The first line contains three integers n m p 1...      E
# 23        102  The first input file line contains integers n ...      A
# 24        102  The first line contains the only integer n 0 n...      B
# 25        103  The first line contains a positive integer n 1...      A
# 26        103  The first line contains two integers the numbe...      B
# 27        103  The first line contains three integers n k and...      C
# 28        103  The first line contains the only positive inte...      D
# 29        103  The first line contains the only number n 1 n ...      E
# ...       ...                                                ...    ...
# 3758       91  The first line contains an integer n 1 n 105 T...      D
# 3759       91  The first line contains numbers n and q 1 n q ...      E
# 3760       92  The first line contains two integers n and m 1...      A
# 3761       92  The first line contains a positive integer x i...      B
# 3762       93  The only line contains four integers n m a b 1...      A
# 3763       93  The only input data file contains three intege...      B
# 3764       93  The input data contain the only integer n 1 n ...      C
# 3765       93  The only line contains two integers L and R 1 ...      D
# 3766       93  The first line contains two integers n and k 1...      E
# 3767       94  The input data contains 11 lines The first lin...      A
# 3768       94  The first line contains an integer m 0 m 10 wh...      B
# 3769       95  The first line contains the only integer n 1 n...      A
# 3770       95  The only line contains a positive integer n 1 ...      B
# 3771       95  The first line contains two integers n and m 1...      C
# 3772       95  The first line contains two integers t and k 1...      D
# 3773       95  The first line contains two integers n and m 1...      E
# 3774       96  The first input line contains a non-empty stri...      A
# 3775       96  The only line contains a positive integer n 1 ...      B
# 3776       97  The first line contains two positive integers ...      A
# 3777       97  The first line contains an integer n 1 n 104 t...      B
# 3778       97  The first line contains an integer n 3 n 100 n...      C
# 3779       97  The first line contains three integers n m and...      D
# 3780       97  The first line contains integers n and m 1 n 1...      E
# 3781       98  The first line contains exactly 6 characters w...      A
# 3782       98  The first line contains a single integer n fro...      B
# 3783       98  The first line contains three space-separated ...      C
# 3784       98  The first line contains an integer n the numbe...      D
# 3785       98  The first line contains space-separated intege...      E
# 3786       99  The first line contains a single number to rou...      A
# 3787       99  The first line contains integer n the number o...      B
#
#                                               main_text   memory_limit  \
# 0     Theatre Square in the capital city of Berland ...  256 megabytes
# 1     In the popular spreadsheets systems for exampl...   64 megabytes
# 2     Nowadays all circuses in Berland have a round ...   64 megabytes
# 3     Tom is interested in power consumption of his ...  256 megabytes
# 4     All cinema halls in Berland are rectangles wit...  256 megabytes
# 5     Not long ago Billy came across such a problem ...  256 megabytes
# 6     This problem differs from one which was on the...  256 megabytes
# 7     Billy investigates the question of applying gr...  256 megabytes
# 8     Soroush s room is a square with side length n ...   64 megabytes
# 9     Kiana thinks two integers are friends if and o...  256 megabytes
# 10    Bijan is new to programming He learned recentl...   64 megabytes
# 11    There are a lot of rumors in the media these d...  256 megabytes
# 12    There are n lamps in a line The lamps are numb...  256 megabytes
# 13    You are given a polynom in form p x x a1 x a2 ...   64 megabytes
# 14    The famous singer Aryo is going to publish a n...   64 megabytes
# 15    Do you know the game Battleship If no look int...   64 megabytes
# 16    Ehsan loves geometry Especially he likes to ro...   64 megabytes
# 17    Aryo has got a lot of intervals for his 2418th...  256 megabytes
# 18    Once when Gerald studied in the first year at ...  256 megabytes
# 19    Little boy Gerald studies at school which is q...  265 megabytes
# 20    At a geometry lesson Gerald was given a task t...  256 megabytes
# 21    Gerald is positioned in an old castle which co...  256 megabytes
# 22    Little Gerald and his coach Mike play an inter...   45 megabytes
# 23    A little boy Gerald entered a clothes shop and...  256 megabytes
# 24    Having watched the last Harry Potter film litt...  265 megabytes
# 25    The average miner Vaganych took refresher cour...  256 megabytes
# 26    Once upon a time a man came to the sea The sea...  256 megabytes
# 27    After all the events in Orlando we all know Sa...  256 megabytes
# 28    As you know the most intelligent beings on the...   70 megabytes
# 29    The Hexadecimal virus loves playing with numbe...  256 megabytes
# ...                                                 ...            ...
# 3758  Yesterday was a fair in a supermarket s grocer...  256 megabytes
# 3759  Today the North Pole hosts an Olympiad in a sp...  256 megabytes
# 3760  There are n walruses sitting in a circle All o...  256 megabytes
# 3761  Little walrus Fangy loves math very much That ...  256 megabytes
# 3762  Throughout Igor K s life he has had many situa...  256 megabytes
# 3763  Students love to celebrate their holidays Espe...  256 megabytes
# 3764  After the Search Ultimate program that searche...  256 megabytes
# 3765  When Igor K was a freshman his professor stric...  256 megabytes
# 3766  Igor K very much likes a multiplayer role play...  256 megabytes
# 3767  Igor K always used to trust his favorite Kashp...  256 megabytes
# 3768  One day Igor K stopped programming and took up...  256 megabytes
# 3769  Petya loves hockey very much One day as he was...  256 megabytes
# 3770  Petya loves lucky numbers Everybody knows that...  256 megabytes
# 3771  Petya loves volleyball very much One day he wa...  256 megabytes
# 3772  Petya likes horse racing very much Horses numb...  256 megabytes
# 3773  Petya loves lucky numbers Everybody knows that...  256 megabytes
# 3774  Petya loves football very much One day as he w...  256 megabytes
# 3775  Petya loves lucky numbers Everybody knows that...  256 megabytes
# 3776  Little Gennady was presented with a set of dom...  256 megabytes
# 3777  A set of points on a plane is called good if f...  256 megabytes
# 3778  One university has just found out about a spor...  256 megabytes
# 3779  The Professor has lost his home robot yet agai...  256 megabytes
# 3780  After a revolution in Berland the new dictator...  256 megabytes
# 3781  Vasilisa the Wise from a far away kingdom got ...  256 megabytes
# 3782  This is the modification of the problem used d...  256 megabytes
# 3783  A very unusual citizen lives in a far away kin...  256 megabytes
# 3784  In a far away kingdom is the famous Lio Shan m...  256 megabytes
# 3785  Shrek and the Donkey as you can guess they als...  256 megabytes
# 3786  In a far away kingdom lived the King the Princ...  256 megabytes
# 3787  In a far away kingdom young pages help to set ...  256 megabytes
#
#                                    output_specification  \
# 0                 Write the needed number of flagstones
# 1     Write n lines each line should contain a cell ...
# 2     Output the smallest possible area of the ancie...
# 3                      Output the answer to the problem
# 4     Output N lines In the i-th line output -1 with...
# 5     Output one number the amount of required A B a...
# 6     In the first line output k the length of the l...
# 7     If greedy algorithm collects any sum in an opt...
# 8     Write a single YES or NO Write YES if and only...
# 9     If the group is friendly write FRIENDS else wr...
# 10    Write sum of the two integers Do not put any l...
# 11    Write a single YES or NO Write YES only if it ...
# 12    Write n words to output Describe the final sta...
# 13    Print the given polynom in a standard way Note...
# 14      Write a single string The name of the new album
# 15    Print n lines YES or NO Print the first word i...
# 16    Write two numbers The result of the rotation Y...
# 17    Write a single integer k the minimum number of...
# 18    Print on the first line the only number m the ...
# 19    Print the only number the number of ways to ge...
# 20    Print YES without the quotes if it is possible...
# 21    Print the only real number the sought expectat...
# 22    Print on the first line the only number the ma...
# 23    Print the only number the least possible sum i...
# 24    Print the number of times a number can be repl...
# 25    Print a single number the minimal number of cl...
# 26    Print NO if the graph is not Cthulhu and FHTAG...
# 27    For each query print if the slot should be emp...
# 28    Print for each scenario of the a b -raid the t...
# 29    Print a single number the minimum price the vi...
# ...                                                 ...
# 3758  Print on the first line the least number of op...
# 3759  For each journalists query print the number of...
# 3760  Print the number of chips the presenter ended ...
# 3761               Print the required number of actions
# 3762  Print a single number the least possible numbe...
# 3763  Print on the first line YES if it is possible ...
# 3764  On the first line print number p which represe...
# 3765  Print a single number the number of different ...
# 3766  Print the single number the damage that will b...
# 3767  Print one line containing 8 characters The pas...
# 3768  Print FAIL if among those five people there ar...
# 3769  Output the only line Petya s resulting string ...
# 3770  Output the least super lucky number that is mo...
# 3771  If taxis can t drive Petya to the destination ...
# 3772  Output t lines In each line print one integer ...
# 3773  If there s no solution output the only number ...
# 3774  Print YES if the situation is dangerous Otherw...
# 3775  Output the least super lucky number that is mo...
# 3776  Print on the first line the number of ways to ...
# 3777  Print on the first line the number of points m...
# 3778  Print the only real number the expected averag...
# 3779  Print in the output file the length of the sma...
# 3780  For each query print on a single line Yes if t...
# 3781  Print the required number of different ways to...
# 3782  Print the sought expected number of tosses as ...
# 3783  Print the maximally possible width of a coffin...
# 3784  Print on the first line number m the smallest ...
# 3785  Print space-separated probabilities that Shrek...
# 3786  If the last number of the integer part is not ...
# 3787  If the pages didn t pour the juice print Exemp...
#
#                                                    tags   time_limit  \
# 0                                              ['math']     1 second
# 1                            ['implementation'/ 'math']   10 seconds
# 2                                  ['geometry'/ 'math']    2 seconds
# 3                                    ['implementation']     1 second
# 4                              ['dp'/ 'implementation']     1 second
# 5                                     ['number theory']    2 seconds
# 6                                                ['dp']     1 second
# 7                           ['constructive algorithms']    2 seconds
# 8                 ['special problem'/ 'implementation']    2 seconds
# 9                 ['special problem'/ 'implementation']    2 seconds
# 10                ['special problem'/ 'implementation']    2 seconds
# 11                       ['special problem'/ 'strings']    5 seconds
# 12                          ['special problem'/ 'math']     1 second
# 13                ['special problem'/ 'implementation']    2 seconds
# 14    ['special problem'/ 'data structures'/ 'implem...    2 seconds
# 15    ['special problem'/ 'dfs and similar'/ 'implem...    2 seconds
# 16              ['special problem'/ 'geometry'/ 'math']    2 seconds
# 17                ['special problem'/ 'greedy'/ 'math']    2 seconds
# 18                                           ['greedy']    2 seconds
# 19           ['binary search'/ 'data structures'/ 'dp']    2 seconds
# 20                           ['implementation'/ 'math']     1 second
# 21    ['dp'/ 'greedy'/ 'probabilities'/ 'sortings'/ ...    2 seconds
# 22                         ['divide and conquer'/ 'dp']  7 5 seconds
# 23                                      ['brute force']    2 seconds
# 24                                   ['implementation']    2 seconds
# 25                 ['greedy'/ 'implementation'/ 'math']    2 seconds
# 26                 ['dfs and similar'/ 'dsu'/ 'graphs']    2 seconds
# 27                ['constructive algorithms'/ 'greedy']    2 seconds
# 28       ['brute force'/ 'data structures'/ 'sortings']    4 seconds
# 29                         ['flows'/ 'graph matchings']    2 seconds
# ...                                                 ...          ...
# 3758    ['constructive algorithms'/ 'graphs'/ 'greedy']    2 seconds
# 3759                    ['data structures'/ 'geometry']    3 seconds
# 3760                         ['implementation'/ 'math']    2 seconds
# 3761                                         ['greedy']     1 second
# 3762                                 ['implementation']    2 seconds
# 3763                                         ['greedy']     1 second
# 3764                  ['brute force'/ 'implementation']    5 seconds
# 3765                         ['dp'/ 'math'/ 'matrices']    2 seconds
# 3766                                     ['dp'/ 'math']    2 seconds
# 3767                      ['implementation'/ 'strings']    2 seconds
# 3768                         ['implementation'/ 'math']     1 second
# 3769                      ['implementation'/ 'strings']    2 seconds
# 3770                                   ['dp'/ 'greedy']    2 seconds
# 3771                                 ['shortest paths']    2 seconds
# 3772                                     ['dp'/ 'math']    2 seconds
# 3773                            ['dp'/ 'dsu'/ 'graphs']     1 second
# 3774                      ['implementation'/ 'strings']    2 seconds
# 3775       ['binary search'/ 'bitmasks'/ 'brute force']    2 seconds
# 3776                  ['brute force'/ 'implementation']   0 5 second
# 3777  ['constructive algorithms'/ 'divide and conquer']    2 seconds
# 3778  ['binary search'/ 'graphs'/ 'math'/ 'shortest ...    2 seconds
# 3779      ['bitmasks'/ 'brute force'/ 'implementation']    4 seconds
# 3780      ['dfs and similar'/ 'dsu'/ 'graphs'/ 'trees']    2 seconds
# 3781                  ['brute force'/ 'implementation']     1 second
# 3782       ['implementation'/ 'probabilities'/ 'trees']    2 seconds
# 3783                     ['geometry'/ 'ternary search']    2 seconds
# 3784                        ['constructive algorithms']    2 seconds
# 3785           ['dp'/ 'games'/ 'math'/ 'probabilities']    2 seconds
# 3786                                        ['strings']    2 seconds
# 3787                     ['implementation'/ 'sortings']   0 5 second
#
#                                 title
# 0                    A Theatre Square
# 1                      B Spreadsheets
# 2            C Ancient Berland Circus
# 3     A Power Consumption Calculation
# 4                    B Cinema Cashier
# 5                      C Digital Root
# 6                              D LCIS
# 7                     E Greedy Change
# 8                A Carpeting the Room
# 9                  B Friendly Numbers
# 10                              C A B
# 11                   D World of Mouth
# 12                  E Lamps in a Line
# 13                          F Polynom
# 14                   G Name the album
# 15                       H Battleship
# 16                         I Rotation
# 17                J Interval Coloring
# 18                         A Homework
# 19                            B Buses
# 20                          C Vectors
# 21                           D Castle
# 22               E Candies and Stones
# 23                          A Clothes
# 24                    B Sum of Digits
# 25        A Testing Pants for Sadness
# 26                          B Cthulhu
# 27                 C Russian Roulette
# 28            D Time to Raid Cowavans
# 29                      E Buying Sets
# ...                               ...
# 3758               D Grocer s Problem
# 3759               E Igloo Skyscraper
# 3760                          A Chips
# 3761                  B Binary Number
# 3762                         A Frames
# 3763                   B End of Exams
# 3764                       C Azembler
# 3765                          D Flags
# 3766                       E Lostborn
# 3767             A Restoring Password
# 3768                        B Friends
# 3769                         A Hockey
# 3770                  B Lucky Numbers
# 3771                     C Volleyball
# 3772                    D Horse Races
# 3773                  E Lucky Country
# 3774                       A Football
# 3775             B Lucky Numbers easy
# 3776                         A Domino
# 3777                       B Superset
# 3778               C Winning Strategy
# 3779              D Robot in Basement
# 3780                        E Leaders
# 3781         A Help Victoria the Wise
# 3782                      B Help King
# 3783            C Help Greg the Dwarf
# 3784                     D Help Monks
# 3785          E Help Shrek and Donkey
# 3786          A Help Far Away Kingdom
# 3787              B Help Chef Gerasim
#
# [3788 rows x 9 columns]
